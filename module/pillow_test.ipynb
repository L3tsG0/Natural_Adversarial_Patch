# %%
from PIL import Image
from pathlib import Path

# %%
img_path = Path("../data/0010001.png")
mask_img_path = Path("../data/0010001_seg0.png")
image = Image.open(img_path).convert("RGBA")
mask = Image.open(mask_img_path).convert("L")

# %%
mask.show()

# %%
cropped = Image.composite(image, Image.new('RGBA', image.size, (255, 255, 255,0)), mask)

# %%
cropped.show()

# %%
from extract_by_mask import extract_by_mask
from PIL import Image
from pathlib import Path
import matplotlib.pyplot as plt
# %matplotlib inline
img_path = Path("../data/0010001.png")
mask_img_path = Path("../data/0010001_seg0.png")
cropped_img = extract_by_mask(img_path=img_path,mask_img_path=mask_img_path)

# %%
plt.imshow(cropped_img)
